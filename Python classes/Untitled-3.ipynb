# %%
import pandas as pd
employees = pd.read_csv(r"C:\Users\saiko\Downloads\employees.csv")
print(employees)

# %%
print(len(employees))
# Out:
# 5

# %%
print(max(employees["Salary"]))
# Out:
# 80000

# %%
print(min(employees["Salary"]))
# Out:
# 50000

# %%
def average_salary(per):
    return sum(per["Salary"]) / len(per)
print(average_salary(employees))
# Out:
# 66000.0
